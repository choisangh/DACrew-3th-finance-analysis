# %% [markdown]
# #session 2. 거시경제 분석

# %% [markdown]
# 안녕하세요, 데이크루 3기 ‘투데이💰︎' 팀입니다!
#
# 팀 투데이는 “투자에 데이터를 이용하다"의 약자입니다. 금융 데이터 수집&가공&모델링을 학습하면서 Financial Domain Knowledge와 Data Analysis Technologies 향상을 목적으로 하고 있습니다.<br>
# 저희는 금융데이터와 AI기술이 만나는 전반적인 과정을 학습하고, 학습한 내용을 바탕으로 데이콘 이용자분들을 위한 콘텐츠를 제작하고 있습니다.
# ‘투데이💰︎’의 두번째 포스팅의 주제는 ‘거시경제분석’입니다.
#
# 아래 링크를 들어가시면 ‘투데이💰︎’의 전 커리큘럼을 보실 수 있습니다.
#
# → <a href="https://dacon.io/competitions/official/235946/codeshare/5502?utm_source=dacrew&utm_medium=441593&utm_campaign=dacrew_2">[투데이💰0편] 금융 데이터 분석에 앞서</a><br>
# → <a href="https://dacon.io/competitions/official/235946/codeshare/5547?utm_source=dacrew&utm_medium=441593&utm_campaign=dacrew_2">[투데이💰1편] 금융 데이터 수집</a>
#
# 본 포스팅은 데이콘 서포터즈 “데이크루" 3기 활동의 일환입니다.

# %% [markdown]
# ## **목차**
# #### 1. 거시경제 이론 이해
# #### 2. 거시경제 지표 비교 분석
# #### 3. 뉴스데이터&NLP활용 경기 지수 개발

# %% [markdown]
# # 1. 거시경제 이론 이해
# ## 거시경제 분석이란?

# %% [markdown]
# 기업이 아무리 높은 내재가치와 잠재력을 지녔어도 경제가 쇠퇴기라면 좋은 평가를 받을 수 없습니다.<br>
# 요즘 같이 물가가 치솟고 경제적으로 어려운 상황 속에서 기업 주가가 갑자기 폭등한다는 건 말이 안되겠죠??<br>
# 현재 경기가 호경기인지 불경기인지 알고 있어야 적절한 투자 타이밍을 포착할 수 있습니다.<br>
# 적어도 경기 불황에 따른 손실은 어느정도 막을 수 있습니다.<br>
# 이와 같은 판단을 하기 위해서 **거시 경제 전반을 분석하는 과정**이 필요합니다.

# %% [markdown]
# ## 경기변동

# %% [markdown]
# <img src="https://t1.daumcdn.net/cfile/tistory/99DAFD4C5D8879CF0B">

# %% [markdown]
# 경기란 한 나라의 경제활동 수준을 의미합니다.<br>
# 경기는 순환하는 특성을 지니고 있습니다. 경기의 상황에 따라서 호경기/불경기로 나뉘는데 불경기에서 호경기, 호경기에서 다시 불경기로 반복적인 순환 과정을 거칩니다.<br>
# 특정 사건으로 인해 경제 불황이 시작되면, 이에 대응한 통화/재정정책으로 경기가 점차 회복되어 호경기로 전환이 됩니다.<br>
# 여기서 다시 경기 과열에 따른 인플레이션에 대비한 통화/재정정책으로 경기가 다시 위축이 되는 상황이 반복됩니다.<br>

# %% [markdown]
# ### 경기 변동의 4 국면
# 상승국면(호황기) : 투자가 활발해지고, 생산재/소비재의 생산이 증가합니다. 금리와 물가가 상승하고, 고용이 증가하고, 임금이 상승합니다.<br>
# 둔화국면 : 과잉 공급으로 인해 물가와 주가가 하락하고, 기업 실정이 나빠져서 실업률이 증가하고, 투자가 감소합니다.<br>
# 하강국면(불황기) : 투자 및 생산 활동이 침체기에 접어들고, 금리와 물가가 하락합니다. 주가 또한 폭락 하는 등 증권시장이 최악의 상황에 접어듭니다.<br>
# 회복국면 : 거래가 회복되면서, 투자 및 생산이 점진적으로 상승합니다.

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/c5bGl2/btrHpeYcrlI/ymGfQ9EAiQdih8hHf1YTk0/img.gif">

# %% [markdown]
# https://kosis.kr/visual/bcc/index/index.do?mb=N<br>
# kosis에서 제공하는 경기순환시계를 통해서 현재 경기가 어느 국면에 접어들었는지 알 수 있습니다.<br>
# 기업실사지수를 기준으로 최근 경기는 둔화국면에 진입한 것을 확인하실 수 있습니다.

# %% [markdown]
# ## 재정정책
# **재정정책이란**, 정부지출과 조세를 변화시켜 경제성장, 물가안정 등의 정책목표를 달성하려는 경제정책입니다.
# > * 확대재정정책 : 정부지출의 증가, 세금 감소 등으로 총수요를 증진시키고 침체된 경제상황을 회복하려는 정책
# * 긴축재정정책 : 정부지출의 감소, 세금 증가 등으로 과열된 경제상황을 안정화시키려는 정책

# %% [markdown]
# ## 통화정책
# **통화정책이란**, 중앙은행이 물가안정 등의 정책목표를 달성하기 위하여 화폐량을 조절하는 정책입니다.
# > * 확대통화정책 : 경제활성화를 위해 화폐량을 증대하려는 정책
# > * 긴축통화정책 : 경제안정화를 위해 화폐량을 감소하는 정책

# %% [markdown]
# ### 통화정책 - 통화량

# %% [markdown]
# * <b>본원통화</b> : 중앙은행 화폐발행액, 시중은행으로 보낸 돈
#   - 현금통화 + 예금은행시재금 + 중앙은행 지급준비예치금<br>
# * 시장에 풀린 본원통화는 크게 다음 두가지 방식으로 유통됩니다.
#    - <b>현금통화 </b> : 현금의 형태로 실제 시장에 풀려 유통되는 통화
#    - <b>지급준비금</b> : 지급준비금 적립대상 채무의 일정비율(지급준비율)에 해당하는 금액을 중앙은행에 지급준비금으로 예치

# %% [markdown]
# * 통화지표 <br>
#    (예) 초기에 10일은 4만원 입금,  이 후 20일은 6만원 입금
#   - <b>평잔</b> : ( ( 40,000 * 10일 ) + ( 60,000 * 20일 ) ) / 30일 = 80,000원
#   - <b>말잔</b> : 10만원
#   - 은행이자는 평잔 기준 입니다.
#   - 통상적으로는 평잔보다 말잔이 높습니다.
#  <table>
#     <tr>
#         <td><img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcZmxkR%2FbtqUeiF5uad%2FNk4LaGuEczfLzPYlsh0rJK%2Fimg.png'></td>
#         <td><img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2Few5rPj%2FbtqUeXhn0Ih%2F7fbSacPBHtreGVgdGF2MfK%2Fimg.png'></td>
#     </tr>
# </table>
# * M1 (협의통화) : 가계 소비내역
# * M2 (광의통화> : 시중에 돈이 얼마나 풀려 있는지를 보여주는 지표
# * Lf (금융기관 유동성) : 금융기관 금융채 유동성
# * L (광의 유동성) : 정부나 기업 유동성

# %% [markdown]
# 통화량과 주가는 양의 상관관계인 경우가 많습니다.<br>
# 시중에 풀려있는 돈(M2)이 많을 수록 증권시장에 흘러들어가는 자금도 많아지기 때문입니다.
# 경제가 침체되고 시장이 얼어붙으면, 중앙은행에서 통화량을 증가시켜서 시장을 활성화 시킵니다.

# %% [markdown]
# ### 통화정책 - 금리

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/cchRHw/btrHOblvlb8/4LAXGtFx9pfsCPSWgZJor0/img.png">

# %% [markdown]
# 금리와 주가는 반대로 움직입니다.<br>
# 대출금리, 채권금리 등 금융 상품의 금리들은 한국은행의 기준금리를 중심으로 높고, 낮아집니다.
# 기준 금리가 인상될 경우 대출 금리 또한 높아지기 때문에 자금 수요자의 이자비용 부담이 커지고,<br>
# 자금 공급자의 입장에서 저위험 투자자산의 수익률 (채권, 예금, 적금 금리)이 높아 지기 때문에 주식 투자의 매력도가 떨어집니다.<br>
# 따라서 기준금리가 높아질 수록 증권시장이 침체됩니다.
# <br>올해 미연준과 한국은행에서 기준 금리 빅스텝이 이어지면서, 주식시장이 지속적으로 침체되는 상황입니다.

# %% [markdown]
# ## 물가

# %% [markdown]
# 물가의 경우 원인에 따라서 증권시장에 미치는 영향이 다릅니다.<br>
# 경제가 활성화 되면서 수요의 증가로 물가가 증가되는 경우에는 주가도 함께 오르지만<br>
# 우크라이나 전쟁과 같은 지정학적 리스크로 인해 원자재, 유가와 같은 생산비용이 갑자기 증가하는 경우에는 주가에도 악영향을 미칩니다.

# %% [markdown]
# ## 환율

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/o2ux2/btrHPJn1rP5/fFhF1oaN00W0nEdf5n0L80/img.png">

# %% [markdown]
# 환율 변동의 원인에 따라서 결과가 다를 수 있습니다.<br>
# 환율 상승 -> 수출 경쟁력 강화로 인한 주가 상승 or 외국인 투자자 매도로 인한 주가 하락 <br>
# 환율 하락 -> 수출 경쟁력 약화로 인한 주가 하락 or 외국인 투자자 매수로 인한 주가 상승

# %% [markdown]
# ## 결론
# 경제는 '환율이 상승하면 무조건 주가가 상승한다'와 같은 만능 공식이 있는 것이 아닙니다.<br>
# 경제 요인이 변동했을때 그 원인에 대해서 철저하게 분석해야만 미래 경제의 흐름을 예측할 수 있습니다. <br>
# 따라서 매일 경제 뉴스를 통해서 최신 경제 소식에 대한 빠른 습득과 본인의 객관적인 판단이 가장 중요합니다.

# %% [markdown]
# # 2. 거시경제 지표 비교 분석

# %% [markdown]
# ## 2-1. 경기지표와 코스피 지수 비교

# %% [markdown]
# 코스피 지수는 코스피 시장에서 거래되는 모든 주식의 가격을 더 한 후 지수화 한 것으로 코스피 시장의 전체 흐름을 나타냅니다. <br>
# 코스피가 상승하면, 코스피 시장이 전반적으로 활성화되고 있음을 의미합니다.

# %%
#pip install pykrx

# %%
#한글폰트 깨짐 방지
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
import pandas as pd
import numpy as np
from pykrx import stock
from pykrx import bond
import datetime                     
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# 코로나 이후부터 최근까지의 코스피 지수가 어떻게 변화했는지 확인해보겠습니다.

# %%
kospi = stock.get_index_ohlcv("20200101", "20220711", "1001") #코스피 지수 ohlcv

# %%
plt.figure(figsize=(12,6))
kospi['종가'].plot() #종가기준 plot

# %% [markdown]
# 코로나 초기때는 코스피 지수가 1500대 까지 폭락했습니다.<br>
# 그 이후 주식시장에 전례없는 호황을 맞이 했고, 코스피 지수 3000대를 돌파했습니다.<br>
# 하지만 현재에 들어선 우크라이나 전쟁, 금리인상 등 여러가지 상황과 겹쳐서 지속적으로 코스피가 하락하는 모습을 확인하실 수 있습니다.<br>
# 최근 주식시장이 침체기에 접어들고 있음을 코스피 지수 데이터를 통해 확인하실 수 있습니다.

# %% [markdown]
# ECOS에서 제공하는 경기 선행 지수와 비교하여 살펴보겠습니다.<br>
# 경기 선행 지수는 실제 경기순환에 앞서 변동하는 개별지표를 가공ㆍ종합하여 만든 지수로 향후 경기변동의 단기 예측에 이용됩니다. <br>

# %%
# ECOS 데이터 호출 함수
def EcosDownload(Statcode, Freq, Begdate, Enddate, Subcode1, Subcode2, Subcode3):
    
    url = 'http://ecos.bok.or.kr/api/StatisticSearch/HA5OFFNUUGG4TD13CMHV/xml/kr/1/100000/%s/%s/%s/%s/%s/%s/%s/'%(Statcode, Freq, Begdate, Enddate, Subcode1, Subcode2, Subcode3)

    raw = requests.get(url)
    xml = BeautifulSoup(raw.text,'xml')

    raw_data = xml.find_all("row")

    date_list = []
    value_list = []

    for item in raw_data:
         
            value = item.find('DATA_VALUE').text.encode('utf-8')
            date_str = item.find('TIME').text
            
            value = float(value)
            try:
                date_list.append(datetime.datetime.strptime(date_str,'%Y%m'))
            except:
                date_list.append(datetime.datetime.strptime(date_str,'%Y%m%d'))
            value_list.append(value)
            
    df = pd.DataFrame(index = date_list)
    
    df['value'] = value_list
      
    return df

# %%
kospi = stock.get_index_ohlcv("20000101", "20220531", "1001") #20년치 코스피 지수 ohlcv

# %%
LEI=EcosDownload('901Y067', 'M', '200001', '202207', 'I16E', '', '') #경기 선행지수 순환변동치 데이터 load

# %%
#시간단위를 맞추기 위해 월단위로 resampling
LEI=LEI.resample('1M').last()
kospi=kospi.resample('1M').last()

# %%
df=pd.merge(LEI,kospi,left_index=True,right_index=True,how='outer')

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(df.index, df['종가'], color='blue')

ax2 = ax1.twinx()
ax2.plot(df.index, df['value'], color='red')

plt.show()

# %% [markdown]
# 경기선행지수(빨강)와 코스피 지수(파랑)를 비교했을 때, 거의 같은 방향으로 흘러가는 것을 보실 수 있습니다.<br>
# 경기선행지수는 100을 기준으로 호경기/불경기를 판단합니다. 최근에는 경기선행지수가 100이하로 떨어진 것으로 보아 현재 경기는 불경기에 진입했다 볼 수 있습니다.
# 경기선행지수의 경우 발표까지 2달의 간격이 존재합니다. 즉 5월의 경기선행지수를 7월에 발표합니다.<br>
# 그러므로 경기선행지수를 통해 경기를 예측한다기 보다는, 현재 경기가 어느 구간인지를 판단하고 투자 의사결정에 활용하는 것이 바람직합니다.

# %% [markdown]
# ## 2-2. 통화량과 코스피 지수 비교

# %%
kospi = stock.get_index_ohlcv("20020101", "20220531", "1001") #20년치 코스피 지수 ohlcv
M2=EcosDownload('101Y003', 'M', '200201', '202205', 'BBHS00', '', '') #본원통화 평잔 데이터 load

# %%
M2.columns=['M2']

# %%
#시간단위를 맞추기 위해 월단위로 resampling
M2=M2.resample('1M').last()
kospi=kospi.resample('1M').last()

# %%
df=pd.merge(M2,kospi,left_index=True,right_index=True,how='outer')

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(df.index, df['종가'], color='blue')

ax2 = ax1.twinx()
ax2.plot(df.index, df['M2'], color='purple')



plt.show()

# %% [markdown]
# 시중에 발행된 통화량은 계속해서 증가하는 것을 볼 수 있습니다.<br>
# 통화를 계속 발행하지 않으면, 통화의 가치가 계속 상승하여 시장에 돈이 풀리지 않기 때문입니다.<br>
# 그래프를 통해 확인할 수 있는 것은 코로나 이후 통화량의 기울기가 조금 가팔라졌다는 점입니다.<br>
# 조금 더 자세한 비교를 위해서 통화 증가량 그래프를 확인해 보겠습니다.

# %%
df['M2_gap']=df['M2']-df['M2'].shift(1)

df=df.dropna()

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(df.index, df['종가'], color='blue')

ax2 = ax1.twinx()
ax2.plot(df.index, df['M2_gap'], color='red')

plt.show()

# %% [markdown]
# 전월 대비 M2 통화의 증가량을 살펴보시면, 코로나 이후 통화 발행량이 급격하게 증가한 것을 볼 수 있습니다. <br>
# 이는 코로나로 인한 사회적 거리두기 등 내수시장이 침체될 것을 우려하여 시중에 돈을 푼 것으로 해석할 수 있습니다.<br>
# 또한 전체적으로 코스피 지수가 상승한 구간에서는 통화 증가량이 하락하고, 코스피 지수가 하락한 구간에서는 통화 증가량이 상승한 것을 보아 통화 유통속도에 의한 시차가 존재하는 것으로 보입니다.

# %% [markdown]
# ## 2-3. 기준 금리와 코스피 지수 비교

# %%
kospi = stock.get_index_ohlcv("20020101", "20220716", "1001") #20년치 코스피 지수 ohlcv
rate=EcosDownload('722Y001', 'M', '200201', '202207', '0101000', '', '') #기준금리 데이터 load

# %%
#시간단위를 맞추기 위해 월단위로 resampling
rate=rate.resample('1M').last()
kospi=kospi.resample('1M').last()

# %%
df=pd.merge(rate,kospi,left_index=True,right_index=True,how='outer')

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(df.index, df['종가'], color='blue')

ax2 = ax1.twinx()
ax2.plot(df.index, df['value'], color='red')

plt.show()

# %% [markdown]
# 리먼브라더스 사태 (2008년)의 경우 글로벌 경제 침체로 경제 활성화를 위해 정부에서 사후적 금리 인하를 시행했고, 이 후 경기가 안정되면서 다시 금리가 인상됐습니다.<br>
# 코로나 초기 내수 경제 침체를 대비해 금리를 인하했고, 이후 포스트 코로나 시대에 발맞춰 단계적 금리 인상했습니다. <br>
# 전체적으로 금리와 코스피 지수가 반대로 가는 성향을 확인하실 수 있습니다.

# %% [markdown]
# ## 2-4. 물가와 코스피 지수 비교

# %%
kospi = stock.get_index_ohlcv("20020101", "20220716", "1001") #20년치 코스피 지수 ohlcv
cp=EcosDownload('901Y009', 'M', '200201', '202207', '0', '', '') #소비자물가지수 데이터 load  
pp=EcosDownload('404Y014', 'M', '200201', '202207', '*AA', '', '') #생산자물가지수 데이터 load

# %%
cp.columns=['cp']
pp.columns=['pp']

# %%
#시간단위를 맞추기 위해 월단위로 resampling
cp=cp.resample('1M').last()
pp=pp.resample('1M').last()
kospi=kospi.resample('1M').last()

# %%
df=pd.merge(cp,kospi,left_index=True,right_index=True,how='outer')
df=pd.merge(df,pp,left_index=True,right_index=True,how='outer')

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(df.index, df['종가'], color='blue')

ax2 = ax1.twinx()
ax2.plot(df.index, df['cp'], color='red')

ax2.plot(df.index, df['pp'], color='green')

plt.show()

# %% [markdown]
# 보통 호경기의 수요의 증가로 인한 물가 상승은 코스피 지수와 같은 방향을 향합니다. 물가가 오를수록 경기가 활성화됨을 의미하므로 주가도 지속적으로 상승합니다.<br>
# 하지만 물가와 코스피가 반대로 가는 경우도 존재합니다.<br>
# 최근 우크라이나 전쟁과 같은 지정학적 리스크나 스태그플레이션 상황에서는 물가가 급상승함에도 코스피 지수는 지속적으로 하락하는 모습을 보실 수 있습니다.<br>
# 우크라이나 전쟁 이후 국제유가가 폭등하면서 생산자 물가(초록) 큰 폭으로 상승하고 있으며, 소비자 물가도 상승 중에 있습니다.

# %% [markdown]
# ## 2-5. 환율과 코스피 지수 비교

# %%
kospi = stock.get_index_ohlcv("20020101", "20220716", "1001") #20년치 코스피 지수 ohlcv
wd=EcosDownload('731Y001', 'D', '20020101', '20220716', '0000001', '', '') #소비자물가지수 데이터 load

# %%
wd.columns=['dollar']

# %%
df=pd.merge(wd,kospi,left_index=True,right_index=True,how='outer')

# %%
df2 = stock.get_market_trading_value_by_date("20070101", "20220716", "KOSPI") #코스피 투자자별 순매수 거래량 데이터

# %%
df=pd.merge(df,df2,left_index=True,right_index=True,how='outer')

# %%
df['외국인합계누적']=df['외국인합계'].cumsum() #외국인 순매수 거래량 누적

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(df.index, df['종가'], color='blue')

ax2 = ax1.twinx()
ax2.plot(df.index, df['dollar'], color='green')

ax2 = ax1.twinx()
ax2.plot(df.index, df['외국인합계누적'], color='red')

plt.show()

# %% [markdown]
# 코스피 지수와 환율(달러)은 반대로 가는 경향이 큽니다.<br>
# 환율(초록)이 상승하면 코스피 지수는 하락하고 환율이 하락하면 코스피 지수가 상승하는 모습을 보이고 있습니다.<br>
# 최근의 경우 미 연준의 빅스텝 이후 환율이 지속적으로 상승하고 있으며, 그에 반해 코스피 지수는 지속적으로 하락 중입니다.<br>
# 특히, 외국인 투자자의 누적 (순매수) 거래량(빨강)이 급감하고 있는 것으로 보아 환율이 외국인 투자자의 의사결정에도 영향을 미친 것으로 보입니다.<br>
# 미국인 투자자의 경우 한국 주식을 통해 10%의 수익을 얻어도, 원/달러 환율이 20% 증가하면 오히려 10%의 손해를 보기 때문에 환율은 외국인 투자자에게 있어 중요한 투자 판단 지표입니다.

# %% [markdown]
# # 3. 뉴스데이터&NLP활용 경기 지수 개발

# %% [markdown]
# Ecos 통계는 보통 월단위로 데이터를 제공합니다. 그리고 통계 발표일과 2개월정도의 격차가 있기 때문에 실제 투자 인사이트를 제공하지는 못하고 전체적인 경제의 사후적 흐름만 파악할 수 있습니다.
# <br>그렇기 때문에 일반적인 투자자들은 매일 아침 경제 뉴스를 통해 현재 경기를 파악하고 있습니다.
# <br>하지만 매일 경제 뉴스를 확인하여 판단하는 것은 번거롭기도 하고, 주관적인 견해가 개입할 여지가 많기 때문에 호황/불황 뉴스의 절대적인 빈도수를 비교하여 보다 객관적인 지표를 만들어서 투자에 활용해보고자 합니다.
# <br> 다음과 같은 단계를 통해 경기 지수를 산출할 수 있습니다.

# %% [markdown]
# * 1. 뉴스데이터 감성 분류 및 빈도수 그루핑
# * 2. BSI 방식 지수화
# * 3. 계절성 제거 (x13-arima) <OS 문제로 생략>
# * 4. 순환변동치 산출 (HP-Filter)

# %% [markdown]
# ## 뉴스데이터 수집
# * 빅카인즈 뉴스 데이터 수집
# * ref : https://www.bigkinds.or.kr/<br>
#
# 뉴스 기사 크롤링을 할 수도 있지만 많은 뉴스 사이트에서 request 방식의 크롤링이 제한이 되어 보통 셀레니움을 활용하여 크롤링을 하는데, 이는 시간이 오래걸린다는 단점이 있습니다. <br>
# 따라서 뉴스 빅데이터를 제공해주는 빅카인즈라는 사이트를 통해서 사전에 뉴스데이터 수집을 진행했습니다.

# %% [markdown]
# ## kr-Finbert 감성 분류모델
# * ref : https://huggingface.co/snunlp/KR-FinBert-SC
# <br>
#
# NLP의 경우 자체적으로 모델 학습을 하는 것보다 이미 학습된 모델을 사용하는 것이 효율적입니다.<br>

# %%
#pip install transformers

# %%
import pandas as pd
from argparse import Namespace
from sklearn.metrics import classification_report
from transformers import pipeline

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("snunlp/KR-FinBert-SC")

model = AutoModelForSequenceClassification.from_pretrained("snunlp/KR-FinBert-SC")
# Out:
# Downloading:   0%|          | 0.00/372 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/140k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/287k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/881 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/387M [00:00<?, ?B/s]

# %%
classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
text = """
주식에서 수천만 원을 잃으니, 정신적 충격에 한동안 일상생활을 할 수가 없더라고요.3년간 대기업에서 일하며 모은 결혼 비용으로 주식에 투자했던 20대 A 씨는 최근 기자와 만나 이같이 하소연했다. 그는 대출까지 받아 약 1억 원을 투자했는데 최근 주가가 고꾸라지면서 수천만 원의 손실을 봤다.A 씨는 계획했던 결혼을 미뤘고, 스트레스 탓에 회사 업무도 못 할 지경이 되자 자의반 타의반으로 사표를 냈다. 폭식으로 건강도 악화된 채로 지금도 스마트폰을 놓지 못한 채 주식창을 들여다보기가 일쑤라고 했다. 최근 주식과 가상화폐 등 자산 가격이 급락하면서 속칭 ‘영끌’(영혼까지 끌어모아) 투자에 나섰다가 큰 손실을 보고 정신적 공황 상태에 빠진 20, 30대가 늘고 있다. 허탈감 속에 관련 상담센터를 찾는 이들도 적지 않다.
"""

# %%
classifier(text)[0]['label']
# Out:
# 'negative'

# %%
text2= """
11일 오후 14시14분 현재 코스닥 종목인 미래에셋대우스팩3호(+29.81%)가 상한가를 기록 중이다. 미래에셋대우스팩3호는 전 거래일 상승(▲90, +4.23%)에 이어 오늘 현재 상한가를 기록 중이다. 미래에셋대우스팩3호의 총 상장 주식수는 648만2000주이며, 이시간 현재 거래량은 583만8131주, 거래대금은 147억2317만6110 원이다.
"""

# %%
classifier(text2)
# Out:
# [{'label': 'positive', 'score': 0.8621386885643005}]

# %% [markdown]
# 최근 뉴스 본문 Text를 이용해 KR-FinBert-SC의 성능을 확인한 결과 어느정도 정확도가 높은 것을 볼 수 있습니다.

# %% [markdown]
# ## 뉴스 데이터 감성 분류
# * 특정 기간의 뉴스데이터를 감성 분류하여 호황/불황을 판단
# * 빅카인즈에서 약 10만건의 경제 뉴스(아주 경제) 데이터 수집

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
newsdf=pd.DataFrame()
for i in range(9):
    news=pd.read_excel("/content/gdrive/My Drive/투.데.이/Data/NewsResult_19900101-20220717 ("+str(i)+").xlsx")[['일자','제목','본문']]
    newsdf=pd.concat([newsdf,news],axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# 사전에 수집한 약 10만건의 뉴스데이터 중 일자, 제목, 본문 부분만 추출했습니다.

# %%
newsdf
# Out:
#         Unnamed: 0  Unnamed: 0.1        일자  \
# 0                0             0  20081231
# 1                1             1  20081231
# 2                2             2  20081231
# 3                3             3  20081231
# 4                4             4  20081231
# ...            ...           ...       ...
# 110249      110249          7063  20220101
# 110250      110250          7064  20220101
# 110251      110251          7065  20220101
# 110252      110252          7066  20220101
# 110253      110253          7067  20220101
#
#                                              제목  \
# 0                     [亞증시 오전] 일부증시 휴장 주요증시 혼조세
# 1                            동양證, 삼성그룹주식투자신탁 공모
# 2                        "새해 증시, 눈높이 낮추고 멀리 봐라"
# 3                         동양종금證, 삼성그룹 알짜 업종에 투자
# 4                    (2일자)재테크 전문가에게 듣는 새해 투자 전략
# ...                                         ...
# 110249     [뉴욕증시 마감] 올해 마지막 거래일 일제히 하락 연간으로는 상승
# 110250  ​합병신고서 '3수' 두올물산, '코스닥→K-OTC' 이사가기 만만찮네
# ...

# %%
def labeling(x):
    label=classifier(x)[0]['label']
    return label

# %%
newsdf['분류']=newsdf['본문'].apply(labeling)

# %%
newsdf['분류'].value_counts()
# Out:
# neutral     60963
# positive    32215
# negative    17076
# Name: 분류, dtype: int64

# %% [markdown]
# 본문 기준으로 감성분류를 진행했기 때문에 '중립'의 결과가 다소 많이 나온 것으로 확인됩니다.

# %%
newsdf['일자']=pd.to_datetime(newsdf['일자'],format='%Y%m%d')
newsdf=newsdf.set_index('일자')

# %%
negative=newsdf[newsdf['분류']=='negative']
positive=newsdf[newsdf['분류']=='positive']

# %%
negative=negative.resample('1D').count() #일 단위 빈도수 리샘플링
negative=negative.resample('1M').sum() #월단위 리샘플링
positive=positive.resample('1D').count() #일 단위 빈도수 리샘플링
positive=positive.resample('1M').sum() #월단위 리샘플링

# %%
final=pd.merge(negative[['분류']],positive[['분류']],left_index=True,right_index=True,how='outer')
final.columns=['부정','긍정']
final=final.fillna(0)
final['지수']=((final['긍정']-final['부정'])/(final['긍정']+final['부정']))*100+100

# %%
final
# Out:
#              부정   긍정          지수
# 일자
# 2008-01-31    8   11  115.789474
# 2008-02-29    6    9  120.000000
# 2008-03-31   28   20   83.333333
# 2008-04-30   25   34  115.254237
# 2008-05-31   24   32  114.285714
# ...         ...  ...         ...
# 2022-03-31   88  682  177.142857
# 2022-04-30  109  566  167.703704
# 2022-05-31  132  439  153.765324
# 2022-06-30   70  191  146.360153
# 2022-07-31   61  104  126.060606
#
# [175 rows x 3 columns]

# %%
kospi = stock.get_index_ohlcv("20160101", "20220711", "1001") #코스피 지수 ohlcv

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(kospi.index, kospi['종가'], color='red')

ax2 = ax1.twinx()
ax2.plot(final.index, final['지수'], color='green')

plt.show()

# %% [markdown]
# ## 순환변동치 산출 (DOUBLE HP FILTER)
# * ref : https://towardsdatascience.com/introduction-to-trend-filtering-with-applications-in-python-d69a58d23b2

# %% [markdown]
# 산출한 지수의 불규칙성을 제거하고 큰 추세를 파악하기 위해서 HP FILTER를 활용하여 순환변동치를 산출합니다.

# %%
import pandas as pd
import numpy as np
import cvxpy 
import scipy
import cvxopt 
import matplotlib.pyplot as plt

# %%
y = final['지수'].to_numpy()
y = np.log(y)
n = y.size
ones_row = np.ones((1, n))
D = scipy.sparse.spdiags(np.vstack((ones_row, -2*ones_row, ones_row)), range(3), n-2, n)

# %%
lambda_list = [0, 0.1, 0.5, 1, 2, 5, 10, 50, 200, 500, 1000, 2000, 5000, 10000, 100000]

# %% [markdown]
# lambda값을 통해서 추세에 대한 디테일한 조정을 할 수 있습니다.

# %%
solver = cvxpy.CVXOPT
reg_norm = 2
fig, ax = plt.subplots(len(lambda_list)//3, 3, figsize=(20,20))
ax = ax.ravel()
ii = 0
for lambda_value in lambda_list:
    x = cvxpy.Variable(shape=n) 
    # x is the filtered trend that we initialize
    objective = cvxpy.Minimize(0.5 * cvxpy.sum_squares(y-x) 
                  + lambda_value * cvxpy.norm(D@x, reg_norm))
    # Note: D@x is syntax for matrix multiplication
    problem = cvxpy.Problem(objective)
    problem.solve(solver=solver, verbose=False)
    ax[ii].plot(np.arange(1, n+1), y, linewidth=1.0, c='b')
    ax[ii].plot(np.arange(1, n+1), np.array(x.value), 'b-', linewidth=1.0, c='r')
    ax[ii].set_xlabel('Time')
    ax[ii].set_ylabel('Log Premium')
    ii+=1
    
plt.tight_layout()
plt.show()

# %%
x = cvxpy.Variable(shape=n) 
objective = cvxpy.Minimize(0.5 * cvxpy.sum_squares(y-x) 
                + 0.5 * cvxpy.norm(D@x, reg_norm))
problem = cvxpy.Problem(objective)
problem.solve(solver=solver, verbose=False)
np.array(x.value)
# Out:
# array([4.65519148, 4.69846286, 4.72465635, 4.73224499, 4.7376927 ,
#        4.75793269, 4.77853539, 4.76744587, 4.74738656, 4.73798641,
#        4.76035319, 4.79604273, 4.81836103, 4.82884712, 4.83203254,
#        4.8262875 , 4.80173056, 4.76912353, 4.75843111, 4.76570288,
#        4.80247506, 4.84096657, 4.85388502, 4.84469212, 4.84196106,
#        4.83922994, 4.82315047, 4.7858215 , 4.7351609 , 4.69637485,
#        4.66659355, 4.63643105, 4.59273676, 4.55052915, 4.53616961,
#        4.55623601, 4.62529818, 4.69198628, 4.71701221, 4.70085836,
#        4.66215913, 4.6333945 , 4.61021201, 4.60763392, 4.64471926,
#        4.6863774 , 4.70766116, 4.70551396, 4.67218047, 4.61294269,
#        4.58710505, 4.60737774, 4.64908986, 4.69253762, 4.7236797 ,
#        4.74397831, 4.76745522, 4.8175916 , 4.89309199, 4.96572344,
#        5.0177688 , 5.05132617, 5.09525898, 5.13557452, 5.16433956,
#        5.18383174, 5.19554621, 5.2046402 , 5.2096397 , 5.21071201,
# ...

# %%
final['순환변동']=np.array(x.value)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## 결과 분석

# %%
plt.rcParams['figure.figsize'] = (12, 6)

fig, ax1 = plt.subplots()
ax1.plot(kospi.index, kospi['종가'], color='red')

ax2 = ax1.twinx()
ax2.plot(final.index, final['순환변동'], color='green')

plt.show()

# %% [markdown]
# 뉴스지수 산출 결과 과거의 경우 대부분 코스피 지수보다 선행하는 특성을 보여줍니다.<br>
# 하지만 최근의 하락장에서는 다소 후행하는 경향을 볼 수 있습니다.<br>
# 뉴스데이터가 부족하거나, 감성 분류된 데이터의 빈도 중 중립의 경우가 많았기 때문에 정확한 결과가 반영이 되지 않아 이러한 현상이 발생한 것으로 보입니다.<br>
# 또한 경기 변동적 요인만 확인하기 위해서 X13-ARIMA 모델을 활용하여 계절조정을 하는 작업이 추가로 진행되어야 하는데 OS의 문제로 생략했기때문에 이러한 결과가 나온 것 일 수 도 있습니다.<br>
# 여러분들이 뉴스 개발을 진행하실때 더 많은 뉴스 데이터를 활용하거나, 계절조정을 추가적으로 해주시면, 더 좋은 결과를 얻을 수 있을 것입니다.
